# %%
import pandas as pd

# dataset with happiness index and other data
columns = ["Country", "Year", "Life Ladder", "Log GDP Per Capita", "Social Support", "Life Expectancy", "Freedom of Choice", "Generosity", "Corruption", "Positive Affect", "Negative Affect", "Confidence in National Government", "Democratic Quality", "Delivery Quality", "d1", "d2", "d3", "d4", "Gini of Household Income"]
data = pd.read_csv("HappinessIndex+.csv", names = columns, header = 0)
data.drop(columns = ["d1", "d2", "d3", "d4"], inplace = True)
data
# Out:
#           Country  Year  Life Ladder  Log GDP Per Capita  Social Support  \
# 0     Afghanistan  2008     3.723590            7.168690        0.450662
# 1     Afghanistan  2009     4.401778            7.333790        0.552308
# 2     Afghanistan  2010     4.758381            7.386629        0.539075
# 3     Afghanistan  2011     3.831719            7.415019        0.521104
# 4     Afghanistan  2012     3.782938            7.517126        0.520637
# ...           ...   ...          ...                 ...             ...
# 1557     Zimbabwe  2013     4.690188            7.565154        0.799274
# 1558     Zimbabwe  2014     4.184451            7.562753        0.765839
# 1559     Zimbabwe  2015     3.703191            7.556052        0.735800
# 1560     Zimbabwe  2016     3.735400            7.538829        0.768425
# 1561     Zimbabwe  2017     3.638300            7.538187        0.754147
#
#       Life Expectancy  Freedom of Choice  Generosity  Corruption  \
# 0           49.209663           0.718114    0.181819    0.881686
# 1           49.624432           0.678896    0.203614    0.850035
# 2           50.008961           0.600127    0.137630    0.706766
# 3           50.367298           0.495901    0.175329    0.731109
# 4           50.709263           0.530935    0.247159    0.775620
# ...               ...                ...         ...         ...
# 1557        48.949745           0.575884   -0.076716    0.830937
# 1558        50.051235           0.642034   -0.045885    0.820217
# 1559        50.925652           0.667193   -0.094585    0.810457
# 1560        51.800068           0.732971   -0.065283    0.723612
# 1561        52.674484           0.752826   -0.066005    0.751208
#
#       Positive Affect  Negative Affect  Confidence in National Government  \
# 0            0.517637         0.258195                           0.612072
# 1            0.583926         0.237092                           0.611545
# 2            0.618265         0.275324                           0.299357
# 3            0.611387         0.267175                           0.307386
# 4            0.710385         0.267919                           0.435440
# ...               ...              ...                                ...
# 1557         0.711885         0.182288                           0.527755
# 1558         0.725214         0.239111                           0.566209
# 1559         0.715079         0.178861                           0.590012
# 1560         0.737636         0.208555                           0.699344
# 1561         0.806428         0.224051                           0.682647
#
#       Democratic Quality  Delivery Quality  Gini of Household Income
# 0              -1.929690         -1.655084                       NaN
# 1              -2.044093         -1.635025                  0.441906
# 2              -1.991810         -1.617176                  0.327318
# 3              -1.919018         -1.616221                  0.336764
# 4              -1.842996         -1.404078                  0.344540
# ...                  ...               ...                       ...
# 1557           -1.026085         -1.526321                  0.555439
# 1558           -0.985267         -1.484067                  0.601080
# 1559           -0.893078         -1.357514                  0.655137
# 1560           -0.863044         -1.371214                  0.596690
# 1561                 NaN               NaN                  0.581484
#
# [1562 rows x 15 columns]

# %%
# dataset with population and population density
columns = ["Country", "Year", "Population", "Population Density", "d1", "d2", "d3", "d4", "d5", "d6", "d7", "d8", "d9", "d10", "d11"]
dataPop = pd.read_csv("migration_population.csv", names = columns, header=0)
dataPop = dataPop.filter(["Country", "Year", "Population", "Population Density"])
data["Year"] = data["Year"].astype('object')
dataPop
# Out:
#           Country  Year   Population  Population Density
# 0      Arab World  2018  419790588.0           37.372365
# 1      Arab World  2017  411898965.0           36.669804
# 2      Arab World  2016  404024433.0           35.968764
# 3      Arab World  2015  396028278.0           35.256897
# 4      Arab World  2014  387907748.0           34.533978
# ...           ...   ...          ...                 ...
# 15571    Zimbabwe  1964    4322861.0           11.174515
# 15572    Zimbabwe  1963    4178726.0           10.801928
# 15573    Zimbabwe  1962    4039201.0           10.441259
# 15574    Zimbabwe  1961    3905034.0           10.094440
# 15575    Zimbabwe  1960    3776681.0                 NaN
#
# [15576 rows x 4 columns]

# %%
data = pd.merge(left=data, right=dataPop, how='left', left_on=['Country','Year'], right_on=['Country', 'Year'])
data
# Out:
#           Country  Year  Life Ladder  Log GDP Per Capita  Social Support  \
# 0     Afghanistan  2008     3.723590            7.168690        0.450662
# 1     Afghanistan  2009     4.401778            7.333790        0.552308
# 2     Afghanistan  2010     4.758381            7.386629        0.539075
# 3     Afghanistan  2011     3.831719            7.415019        0.521104
# 4     Afghanistan  2012     3.782938            7.517126        0.520637
# ...           ...   ...          ...                 ...             ...
# 1557     Zimbabwe  2013     4.690188            7.565154        0.799274
# 1558     Zimbabwe  2014     4.184451            7.562753        0.765839
# 1559     Zimbabwe  2015     3.703191            7.556052        0.735800
# 1560     Zimbabwe  2016     3.735400            7.538829        0.768425
# 1561     Zimbabwe  2017     3.638300            7.538187        0.754147
#
#       Life Expectancy  Freedom of Choice  Generosity  Corruption  \
# 0           49.209663           0.718114    0.181819    0.881686
# 1           49.624432           0.678896    0.203614    0.850035
# 2           50.008961           0.600127    0.137630    0.706766
# 3           50.367298           0.495901    0.175329    0.731109
# 4           50.709263           0.530935    0.247159    0.775620
# ...               ...                ...         ...         ...
# 1557        48.949745           0.575884   -0.076716    0.830937
# 1558        50.051235           0.642034   -0.045885    0.820217
# 1559        50.925652           0.667193   -0.094585    0.810457
# 1560        51.800068           0.732971   -0.065283    0.723612
# 1561        52.674484           0.752826   -0.066005    0.751208
#
#       Positive Affect  Negative Affect  Confidence in National Government  \
# 0            0.517637         0.258195                           0.612072
# 1            0.583926         0.237092                           0.611545
# 2            0.618265         0.275324                           0.299357
# 3            0.611387         0.267175                           0.307386
# 4            0.710385         0.267919                           0.435440
# ...               ...              ...                                ...
# 1557         0.711885         0.182288                           0.527755
# 1558         0.725214         0.239111                           0.566209
# 1559         0.715079         0.178861                           0.590012
# 1560         0.737636         0.208555                           0.699344
# 1561         0.806428         0.224051                           0.682647
#
#       Democratic Quality  Delivery Quality  Gini of Household Income  \
# 0              -1.929690         -1.655084                       NaN
# 1              -2.044093         -1.635025                  0.441906
# 2              -1.991810         -1.617176                  0.327318
# 3              -1.919018         -1.616221                  0.336764
# 4              -1.842996         -1.404078                  0.344540
# ...                  ...               ...                       ...
# 1557           -1.026085         -1.526321                  0.555439
# 1558           -0.985267         -1.484067                  0.601080
# 1559           -0.893078         -1.357514                  0.655137
# 1560           -0.863044         -1.371214                  0.596690
# 1561                 NaN               NaN                  0.581484
#
#       Population  Population Density
# 0     27722276.0           42.462819
# 1     28394813.0           43.492959
# 2     29185507.0           44.704082
# 3     30117413.0           46.131503
# 4     31161376.0           47.730564
# ...          ...                 ...
# 1557  13350356.0           34.510420
# 1558  13586681.0           35.121316
# 1559  13814629.0           35.710557
# 1560  14030390.0           36.268295
# 1561  14236745.0           36.801719
#
# [1562 rows x 17 columns]

# %%
#data.to_csv("dataComplete.csv", index = False)

# %%
import pandas as pd
from sklearn.decomposition import PCA

data.set_index(['Country','Year'], inplace=True, drop=True)

data.dropna(inplace=True)

y = data["Life Ladder"]

data.drop("Life Ladder",axis=1,inplace=True)

numComponents = 2
pca = PCA(n_components=numComponents)
pca.fit(data)

projected = pca.transform(data)
projected = pd.DataFrame(projected,columns=['pc1','pc2'],index=range(1,len(data.index)+1))
print(projected)

X = data

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import numpy as np

# Create linear regression object
regr = linear_model.LinearRegression()


# Fit regression model to the training set
regr.fit(X_train, y_train)



# Apply model to the test set
y_pred = regr.predict(X_test)


# Evaluate the results
print("Root mean squared error = %.4f" %np.sqrt(mean_squared_error(y_test, y_pred)) )
print("R-square = %.4f" % r2_score(y_test, y_pred) )
print('Slope Coefficients:', regr.coef_ )
print('Intercept:', regr.intercept_ )

plt.scatter(y_test, y_pred, color='black')
plt.title('Comparison between true and predicted values')
plt.xlabel('True values for y')
plt.ylabel('Predicted values for y')
# Out:
#               pc1         pc2
# 1   -1.676048e+07 -146.576080
# 2   -1.596978e+07 -145.479758
# 3   -1.503788e+07 -144.187829
# 4   -1.399392e+07 -142.740586
# 5   -1.288570e+07 -141.204435
# ..            ...         ...
# 798 -3.204016e+07 -153.937332
# 799 -3.180494e+07 -153.361125
# 800 -3.156861e+07 -152.782625
# 801 -3.134066e+07 -152.224970
# 802 -3.112490e+07 -151.697067
#
# [802 rows x 2 columns]
# Root mean squared error = 0.5182
# R-square = 0.8012
# Slope Coefficients: [ 3.20243587e-01  1.61124296e+00  2.82851632e-02  1.27818573e+00
#   5.94234369e-01 -1.48061589e+00  2.03109146e+00  5.08718085e-01
#  -1.07996075e+00 -2.17938201e-01  8.36288039e-02 -7.07620659e-01
#   1.82199729e-10 -8.06728097e-05]
# Intercept: -1.171210455840085
# Text(0, 0.5, 'Predicted values for y')
