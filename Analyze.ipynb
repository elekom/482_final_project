# %%
import pandas as pd
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')

data = pd.read_csv("dataComplete.csv")
data
# Out:
#           Country  Year  Life Ladder  Log GDP Per Capita  Social Support  \
# 0     Afghanistan  2008     3.723590            7.168690        0.450662
# 1     Afghanistan  2009     4.401778            7.333790        0.552308
# 2     Afghanistan  2010     4.758381            7.386629        0.539075
# 3     Afghanistan  2011     3.831719            7.415019        0.521104
# 4     Afghanistan  2012     3.782938            7.517126        0.520637
# ...           ...   ...          ...                 ...             ...
# 1557     Zimbabwe  2013     4.690188            7.565154        0.799274
# 1558     Zimbabwe  2014     4.184451            7.562753        0.765839
# 1559     Zimbabwe  2015     3.703191            7.556052        0.735800
# 1560     Zimbabwe  2016     3.735400            7.538829        0.768425
# 1561     Zimbabwe  2017     3.638300            7.538187        0.754147
#
#       Life Expectancy  Freedom of Choice  Generosity  Corruption  \
# ...

# %%
dataYear = data.filter(['Life Ladder', 'Year']).dropna()
corr = np.corrcoef(dataYear['Life Ladder'], dataYear['Year'])[0,1]
print(corr)
plt.scatter(dataYear['Year'], dataYear['Life Ladder'])
plt.xlabel('Year')
plt.ylabel('Life Ladder')
plt.title('Life Ladders per Year 2005-2017')
plt.show()
# Out:
# -0.014505375152495132

# %%
dataLogGDP = data.filter(['Life Ladder', 'Log GDP Per Capita']).dropna()
corr = np.corrcoef(dataLogGDP['Life Ladder'], dataLogGDP['Log GDP Per Capita'])[0,1]
print(corr)
plt.scatter(dataLogGDP['Log GDP Per Capita'], dataLogGDP['Life Ladder'])
plt.xlabel('Log GDP Per Capita')
plt.ylabel('Life Ladder')
plt.title('Life Ladder per Log GDP')
plt.show()
# Out:
# 0.5605898927761356

# %%
dataSocial = data.filter(['Life Ladder', 'Social Support']).dropna()
corr = np.corrcoef(dataSocial['Life Ladder'], dataSocial['Social Support'])[0,1]
print(corr)
plt.scatter(dataSocial['Social Support'], dataSocial['Life Ladder'])
plt.xlabel('Social Support')
plt.ylabel('Life Ladder')
plt.title('Life Ladder given Social Support')
plt.show()
# Out:
# 0.576592531668646

# %%
dataLifeExp = data.filter(['Life Ladder', 'Life Expectancy']).dropna()
corr = np.corrcoef(dataLifeExp['Life Ladder'], dataLifeExp['Life Expectancy'])[0,1]
print(corr)
plt.scatter(dataLifeExp['Life Expectancy'], dataLifeExp['Life Ladder'])
plt.xlabel('Life Expectancy')
plt.ylabel('Life Ladder')
plt.title('Life Ladder given Life Expectancy')
plt.show()
# Out:
# 0.6303079069879869

# %%
dataFreedom = data.filter(['Life Ladder', 'Freedom of Choice']).dropna()
corr = np.corrcoef(dataFreedom['Life Ladder'], dataFreedom['Freedom of Choice'])[0,1]
print(corr)
plt.scatter(dataFreedom['Freedom of Choice'], dataFreedom['Life Ladder'])
plt.xlabel('Freedom of Choice')
plt.ylabel('Life Ladder')
plt.title('Life Ladder given Freedom of Choice')
plt.show()
# Out:
# 0.4083412733163576

# %%
dataGenerosity = data.filter(['Life Ladder', 'Generosity']).dropna()
corr = np.corrcoef(dataGenerosity['Life Ladder'], dataGenerosity['Generosity'])[0,1]
print(corr)
plt.scatter(dataGenerosity['Generosity'], dataGenerosity['Life Ladder'])
plt.xlabel('Generosity')
plt.ylabel('Life Ladder')
plt.title('Life Ladder given Generosity')
plt.show()
# Out:
# 0.19903757064213212

# %%
dataCorruption = data.filter(['Life Ladder', 'Corruption']).dropna()
corr = np.corrcoef(dataCorruption['Life Ladder'], dataCorruption['Corruption'])[0,1]
print(corr)
plt.scatter(dataCorruption['Corruption'], dataCorruption['Life Ladder'])
plt.xlabel('Corruption')
plt.ylabel('Life Ladder')
plt.title('Life Ladder given Corruption')
plt.show()
# Out:
# -0.32743014548786076

# %%
dataPosAffect = data.filter(['Life Ladder', 'Positive Affect']).dropna()
corr = np.corrcoef(dataPosAffect['Life Ladder'], dataPosAffect['Positive Affect'])[0,1]
print(corr)
plt.scatter(dataPosAffect['Positive Affect'], dataPosAffect['Life Ladder'])
plt.xlabel('Positive Affect')
plt.ylabel('Life Ladder')
plt.title('Life Ladder given Positive Affect')
plt.show()
# Out:
# 0.44955342263885595

# %%
dataNegAffect = data.filter(['Life Ladder', 'Negative Affect']).dropna()
corr = np.corrcoef(dataNegAffect['Life Ladder'], dataNegAffect['Negative Affect'])[0,1]
print(corr)
plt.scatter(dataNegAffect['Negative Affect'], dataNegAffect['Life Ladder'])
plt.xlabel('Negative Affect')
plt.ylabel('Life Ladder')
plt.title('Life Ladder given Negative Affect')
plt.show()
# Out:
# -0.2609074165887671

# %%
dataGovConfidence = data.filter(['Life Ladder', 'Confidence in National Government']).dropna()
corr = np.corrcoef(dataGovConfidence['Life Ladder'], dataGovConfidence['Confidence in National Government'])[0,1]
print(corr)
plt.scatter(dataGovConfidence['Confidence in National Government'], dataGovConfidence['Life Ladder'])
plt.xlabel('Confidence in National Government')
plt.ylabel('Life Ladder')
plt.title('Life Ladder given Confidence in National Government')
plt.show()
# Out:
# -0.0750295162001923

# %%
dataDemQuality = data.filter(['Life Ladder', 'Democratic Quality']).dropna()
corr = np.corrcoef(dataDemQuality['Life Ladder'], dataDemQuality['Democratic Quality'])[0,1]
print(corr)
plt.scatter(dataDemQuality['Democratic Quality'], dataDemQuality['Life Ladder'])
plt.xlabel('Democratic Quality')
plt.ylabel('Life Ladder')
plt.title('Life Ladder given Democratic Quality')
plt.show()
# Out:
# 0.5770938826126243

# %%
dataDeliveryQuality = data.filter(['Life Ladder', 'Delivery Quality']).dropna()
corr = np.corrcoef(dataDeliveryQuality['Life Ladder'], dataDeliveryQuality['Delivery Quality'])[0,1]
print(corr)
plt.scatter(dataDeliveryQuality['Delivery Quality'], dataDeliveryQuality['Life Ladder'])
plt.xlabel('Delivery Quality')
plt.ylabel('Life Ladder')
plt.title('Life Ladder given Delivery Quality')
plt.show()
# Out:
# 0.672264876073428

# %%
dataGini = data.filter(['Life Ladder', 'Gini of Household Income']).dropna()
corr = np.corrcoef(dataGini['Life Ladder'], dataGini['Gini of Household Income'])[0,1]
print(corr)
plt.scatter(dataGini['Gini of Household Income'], dataGini['Life Ladder'])
plt.xlabel('Gini of Household Income')
plt.ylabel('Life Ladder')
plt.title('Life Ladder given Gini of Household Income')
plt.show()
# Out:
# -0.11272243504755179

# %%
dataPop = data.filter(['Life Ladder', 'Population']).dropna()
corr = np.corrcoef(dataPop['Life Ladder'], dataPop['Population'])[0,1]
print(corr)
plt.scatter(dataPop['Population'], dataPop['Life Ladder'])
plt.xlabel('Population')
plt.ylabel('Life Ladder')
plt.title('Life Ladder given Population')
plt.show()
# Out:
# -0.03358752919230856

# %%
dataPopDensity = data.filter(['Life Ladder', 'Population Density']).dropna()
corr = np.corrcoef(dataPopDensity['Life Ladder'], dataPopDensity['Population Density'])[0,1]
print(corr)
plt.scatter(dataPopDensity['Population Density'], dataPopDensity['Life Ladder'])
plt.xlabel('Population Density')
plt.ylabel('Life Ladder')
plt.title('Life Ladder given Population Density')
plt.show()
# Out:
# 0.09736473185542781

# %%
import statsmodels.api as sm
from sklearn.model_selection import train_test_split

# Iteratively choosing predictors with test_size= 0.25 and random_state = 1
# based on correlations with target attribute seen above
predictor = data.filter(['Log GDP Per Capita']) # r-sq: 0.2938, rmse: 0.9103
predictor = data.filter(['Social Support']) # r-sq: 0.4301, rmse: 0.8177
predictor = data.filter(['Life Expectancy']) # r-sq: 0.317, rmse: 0.8952
predictor = data.filter(['Freedom of Choice']) # r-sq: 0.1943, rmse: 0.9723
predictor = data.filter(['Generosity']) # r-sq: 0.0598, rmse: 1.0504          OUT
predictor = data.filter(['Corruption']) # r-sq: 0.097, rmse: 1.0294           OUT
predictor = data.filter(['Delivery Quality']) # r-sq: 0.4621, rmse: 0.7945
predictor = data.filter(['Democratic Quality']) # r-sq: 0.3304, rmse: 0.8864
predictor = data.filter(['Positive Affect']) # r-sq: 0.2234, rmse: 0.9546


predictor = data.filter(['Social Support', 'Delivery Quality']) # r-sq: 0.5935, rmse: 0.6906
predictor = data.filter(['Social Support', 'Life Expectancy']) # r-sq: 0.5105, rmse: 0.7579
predictor = data.filter(['Delivery Quality', 'Life Expectancy']) # r-sq: 0.5214, rmse: 0.7494
predictor = data.filter(['Social Support', 'Delivery Quality', 'Life Expectancy']) # r-sq: 0.6209, rmse: 0.6669

predictor = data.filter(['Social Support', 'Delivery Quality', 'Democratic Quality']) # r-sq: 0.5988, rmse: 0.6862
predictor = data.filter(['Social Support', 'Delivery Quality', 'Life Expectancy', 'Democratic Quality']) # r-sq: 0.6238, rmse: 0.6644


predictor = data.filter(['Social Support', 'Delivery Quality', 'Life Expectancy', 'Democratic Quality', 'Log GDP Per Capita']) # r-sq: 0.624, rmse: 0.6642 NOT ENOUGH DIFF
predictor = data.filter(['Social Support', 'Delivery Quality', 'Life Expectancy', 'Democratic Quality', 'Positive Affect']) # r-sq: 0.6415, rmse: 0.6486
predictor = data.filter(['Social Support', 'Delivery Quality', 'Life Expectancy', 'Democratic Quality', 'Freedom of Choice']) # r-sq: 0.6399, rmse: 0.65
predictor = data.filter(['Social Support', 'Delivery Quality', 'Life Expectancy', 'Democratic Quality', 'Positive Affect', 'Log GDP Per Capita']) # r-sq: 0.6417, rmse: 0.6484  NOT ENOUGH DIFF
predictor = data.filter(['Social Support', 'Delivery Quality', 'Life Expectancy', 'Democratic Quality', 'Positive Affect', 'Freedom of Choice']) # r-sq: 0.6463, rmse: 0.6442 NOT ENOUGH DIFF
#highest r-sq, lowest rmse but likely overfit
predictor = data.filter(['Year','Log GDP Per Capita','Social Support','Life Expectancy','Freedom of Choice','Generosity','Corruption','Delivery Quality','Democratic Quality']) # r-sq: 0.6706, rmse: 0.6217 


# CHOSEN PREDICTORS
predictor = data.filter(['Social Support', 'Delivery Quality', 'Life Expectancy', 'Democratic Quality', 'Positive Affect']) # r-sq: 0.6415, rmse: 0.6486
target = data.filter(['Life Ladder'])

X = predictor
y = target['Life Ladder']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25,random_state=1)
model = sm.OLS(y_train, X_train).fit()
predictions = model.predict(X_test)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            Life Ladder   R-squared:                       0.984
# Model:                            OLS   Adj. R-squared:                  0.984
# Method:                 Least Squares   F-statistic:                 1.434e+04
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):               0.00
# Time:                        12:00:42   Log-Likelihood:                -1245.9
# No. Observations:                1171   AIC:                             2502.
# Df Residuals:                    1166   BIC:                             2527.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...
